# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ITERATESMAX = 100 # You can adjust this value as needed 
C = 10 # Adjust C value as needed
alpha = 0.1 # Adjust alpha value as needed
exponent1 = 2 # Adjust exponent1 value as needed
exponent2 = 0.5 # Adjust exponent2 value as needed
x1 = 1
x2 = 1 
alpha1 = 0 
alpha2 = 0
x1_values = np.zeros(ITERATESMAX)
x2_values = np.zeros(ITERATESMAX)

for i in range(ITERATESMAX):
# if (x1 + x2 <= C + alpha1 + alpha2): # when alpha is large it pushes the const boundary out
    if (x1 + x2 <= C):
        # Additive increase phase 
        print('Additive I')
        alpha1 = alpha * np.power(x1, exponent1) 
        alpha2 = alpha * np.log(x2 + 1)
        x1 = x1 + alpha1
        x2 = x2 + alpha2
    else:
    # Simulate network condition (for example, congestion) 
        print('Multiplicative D')
        beta1 = exponent1
        beta2 = exponent2
        x1 = x1 * beta1 
        x2 = x2 * beta2
        
        # pause(1)
    
    # Store values in arrays 
    x1_values[i] = x1 
    x2_values[i] = x2

# Display the final values 
print("Final x1:", x1) 
print("Final x2:", x2)

#The following figure shows that the two flows converge to an equilibrium that favors User 2 with the following alpha update:
# alpha1 = alpha * np.power(x1, exponent1) 
# alpha2 = alpha * np.log(x2 + 1)
# Out:
# Additive I
# Additive I
# Additive I
# Additive I
# Additive I
# Additive I
# Additive I
# Additive I
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Multiplicative D
# Final x1: 6.118665938262676e+27
# Final x2: 3.1593474536802015e-27

# %%
ITERATESMAX = 100 # You can adjust this value as needed 
C = 10 # Adjust C value as needed
alpha = 1 # Adjust alpha value as needed
beta = 0.5
exponent1 = 2 # Adjust exponent1 value as needed
exponent2 = 0.5 # Adjust exponent2 value as needed
x1 = 2
x2 = 5 
alpha1 = 0 
alpha2 = 0
x1_values = np.zeros(ITERATESMAX)
x2_values = np.zeros(ITERATESMAX)
plot_values = []

for i in range(ITERATESMAX):
# if (x1 + x2 <= C + alpha1 + alpha2): # when alpha is large it pushes the const boundary out
    if (x1 + x2 <= C):
        # Additive increase phase 
        print('Additive I')
        alpha1 = alpha * np.power(x1, exponent1) 
        alpha2 = alpha * np.log(x2 + 1)
        x1 = x1 + alpha
        x2 = x2 + alpha
    else:
    # Simulate network condition (for example, congestion) 
        print('Multiplicative D')
        beta1 = exponent1
        beta2 = exponent2
        x1 = x1 * beta 
        x2 = x2 * beta
        
        # pause(1)
    
    # Store values in arrays 
    x1_values[i] = x1 
    x2_values[i] = x2
    plot_values.append((x1,x2))

print(x1_values)
print(x2_values)
# Display the final values 
print("Final x1:", x1) 
print("Final x2:", x2)

# # plot the values of user 1
# plt.plot(x1_values, label='x1')

# plot the values (2 flows)
plt.figure(figsize = (8, 8))

plt.plot(x1_values, x2_values, '-o', label='AIMD Iterates')
plt.xlabel('User 1\'s Allocation, X1')
plt.ylabel('User 2\'s Allocation, X2')
plt.title('AIMD Algorithm Simulation')

# fairness_line = np.linspace(0, C, ITERATESMAX)  # Fairness line
# plt.plot(fairness_line, fairness_line, '--', label='Fairness Line')
plt.plot([0,C], [0,C], '--', label='Fairness Line')

# capacity_line_x = np.linspace(C, 0)         # Capacity line x values
# capacity_line_y = np.linspace(0, C)         # Capacity line y values
# plt.plot(capacity_line_x, capacity_line_y,'-', label='Efficiency Line')
plt.plot([0,C], [C,0],'-', label='Efficiency Line')

# plt.xlim(0, C)
# plt.ylim(0, C)
plt.grid()
plt.legend()
plt.show()

#The following figure shows that the two flows converge to an equilibrium that favors User 2 with the following alpha update:
# alpha1 = alpha * np.power(x1, exponent1) 
# alpha2 = alpha * np.log(x2 + 1)
# Out:
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# [3.         4.         2.         3.         4.         5.
#  2.5        3.5        4.5        5.5        2.75       3.75
#  4.75       5.75       2.875      3.875      4.875      5.875
#  2.9375     3.9375     4.9375     5.9375     2.96875    3.96875
#  4.96875    5.96875    2.984375   3.984375   4.984375   5.984375
#  2.9921875  3.9921875  4.9921875  5.9921875  2.99609375 3.99609375
#  4.99609375 5.99609375 2.99804688 3.99804688 4.99804688 5.99804688
#  2.99902344 3.99902344 4.99902344 5.99902344 2.99951172 3.99951172
#  4.99951172 5.99951172 2.99975586 3.99975586 4.99975586 5.99975586
#  2.99987793 3.99987793 4.99987793 5.99987793 2.99993896 3.99993896
#  4.99993896 5.99993896 2.99996948 3.99996948 4.99996948 5.99996948
#  2.99998474 3.99998474 4.99998474 5.99998474 2.99999237 3.99999237
#  4.99999237 5.99999237 2.99999619 3.99999619 4.99999619 5.99999619
#  2.99999809 3.99999809 4.99999809 5.99999809 2.99999905 3.99999905
#  4.99999905 5.99999905 2.99999952 3.99999952 4.99999952 5.99999952
#  2.99999976 3.99999976 4.99999976 5.99999976 2.99999988 3.99999988
#  4.99999988 5.99999988 2.99999994 3.99999994]
# [6.         7.         3.5        4.5        5.5        6.5
#  3.25       4.25       5.25       6.25       3.125      4.125
#  5.125      6.125      3.0625     4.0625     5.0625     6.0625
#  3.03125    4.03125    5.03125    6.03125    3.015625   4.015625
#  5.015625   6.015625   3.0078125  4.0078125  5.0078125  6.0078125
#  3.00390625 4.00390625 5.00390625 6.00390625 3.00195312 4.00195312
#  5.00195312 6.00195312 3.00097656 4.00097656 5.00097656 6.00097656
#  3.00048828 4.00048828 5.00048828 6.00048828 3.00024414 4.00024414
#  5.00024414 6.00024414 3.00012207 4.00012207 5.00012207 6.00012207
#  3.00006104 4.00006104 5.00006104 6.00006104 3.00003052 4.00003052
#  5.00003052 6.00003052 3.00001526 4.00001526 5.00001526 6.00001526
#  3.00000763 4.00000763 5.00000763 6.00000763 3.00000381 4.00000381
#  5.00000381 6.00000381 3.00000191 4.00000191 5.00000191 6.00000191
#  3.00000095 4.00000095 5.00000095 6.00000095 3.00000048 4.00000048
#  5.00000048 6.00000048 3.00000024 4.00000024 5.00000024 6.00000024
#  3.00000012 4.00000012 5.00000012 6.00000012 3.00000006 4.00000006
#  5.00000006 6.00000006 3.00000003 4.00000003]
# Final x1: 3.9999999403953552
# Final x2: 4.000000029802322

# %%
relative_difference = abs(x1 - x2) / max(x1, x2)
print(relative_difference)
# Out:
# 2.235174162423803e-08

# %%
relative_difference = abs(x1 - x2) / max(x1, x2)
print(relative_difference)
# Out:
# 0.0

# %%
np.linspace(C, 0)
# Out:
# array([10.        ,  9.79591837,  9.59183673,  9.3877551 ,  9.18367347,
#         8.97959184,  8.7755102 ,  8.57142857,  8.36734694,  8.16326531,
#         7.95918367,  7.75510204,  7.55102041,  7.34693878,  7.14285714,
#         6.93877551,  6.73469388,  6.53061224,  6.32653061,  6.12244898,
#         5.91836735,  5.71428571,  5.51020408,  5.30612245,  5.10204082,
#         4.89795918,  4.69387755,  4.48979592,  4.28571429,  4.08163265,
#         3.87755102,  3.67346939,  3.46938776,  3.26530612,  3.06122449,
#         2.85714286,  2.65306122,  2.44897959,  2.24489796,  2.04081633,
#         1.83673469,  1.63265306,  1.42857143,  1.2244898 ,  1.02040816,
#         0.81632653,  0.6122449 ,  0.40816327,  0.20408163,  0.        ])

# %%
np.linspace(0,C)
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
# plt.plot(x1_values, label='x1')
plt.figure(figsize = (10,10))
print(x2_values)
plt.plot(x2_values, '-o', label='x2')
# Out:
# [6.         7.         3.5        4.5        5.5        6.5
#  3.25       4.25       5.25       6.25       3.125      4.125
#  5.125      6.125      3.0625     4.0625     5.0625     6.0625
#  3.03125    4.03125    5.03125    6.03125    3.015625   4.015625
#  5.015625   6.015625   3.0078125  4.0078125  5.0078125  6.0078125
#  3.00390625 4.00390625 5.00390625 6.00390625 3.00195312 4.00195312
#  5.00195312 6.00195312 3.00097656 4.00097656 5.00097656 6.00097656
#  3.00048828 4.00048828 5.00048828 6.00048828 3.00024414 4.00024414
#  5.00024414 6.00024414 3.00012207 4.00012207 5.00012207 6.00012207
#  3.00006104 4.00006104 5.00006104 6.00006104 3.00003052 4.00003052
#  5.00003052 6.00003052 3.00001526 4.00001526 5.00001526 6.00001526
#  3.00000763 4.00000763 5.00000763 6.00000763 3.00000381 4.00000381
#  5.00000381 6.00000381 3.00000191 4.00000191 5.00000191 6.00000191
#  3.00000095 4.00000095 5.00000095 6.00000095 3.00000048 4.00000048
#  5.00000048 6.00000048 3.00000024 4.00000024 5.00000024 6.00000024
#  3.00000012 4.00000012 5.00000012 6.00000012 3.00000006 4.00000006
#  5.00000006 6.00000006 3.00000003 4.00000003]

# %%
x2_values
# Out:
# array([6.        , 7.        , 3.5       , 4.5       , 5.5       ,
#        6.5       , 3.25      , 4.25      , 5.25      , 6.25      ,
#        3.125     , 4.125     , 5.125     , 6.125     , 3.0625    ,
#        4.0625    , 5.0625    , 6.0625    , 3.03125   , 4.03125   ,
#        5.03125   , 6.03125   , 3.015625  , 4.015625  , 5.015625  ,
#        6.015625  , 3.0078125 , 4.0078125 , 5.0078125 , 6.0078125 ,
#        3.00390625, 4.00390625, 5.00390625, 6.00390625, 3.00195312,
#        4.00195312, 5.00195312, 6.00195312, 3.00097656, 4.00097656,
#        5.00097656, 6.00097656, 3.00048828, 4.00048828, 5.00048828,
#        6.00048828, 3.00024414, 4.00024414, 5.00024414, 6.00024414,
#        3.00012207, 4.00012207, 5.00012207, 6.00012207, 3.00006104,
#        4.00006104, 5.00006104, 6.00006104, 3.00003052, 4.00003052,
#        5.00003052, 6.00003052, 3.00001526, 4.00001526, 5.00001526,
#        6.00001526, 3.00000763, 4.00000763, 5.00000763, 6.00000763,
#        3.00000381, 4.00000381, 5.00000381, 6.00000381, 3.00000191,
#        4.00000191, 5.00000191, 6.00000191, 3.00000095, 4.00000095,
#        5.00000095, 6.00000095, 3.00000048, 4.00000048, 5.00000048,
#        6.00000048, 3.00000024, 4.00000024, 5.00000024, 6.00000024,
#        3.00000012, 4.00000012, 5.00000012, 6.00000012, 3.00000006,
#        4.00000006, 5.00000006, 6.00000006, 3.00000003, 4.00000003])

# %%
import math
import matplotlib.pyplot as plt
 
def AIMD(a:int=1, b:float=0.5, cwnd:int=10, data_packet:tuple=(None, "Dropped"), RTT_tracker:list=[])->list:
    """This function mimics the Additive Increase and Multiplicative Decrease Mechanism in TCP Congestion Control.
 
    Parameters
    ----------
    a: int-type
    This constant controls the rate of Additive Increase. This optimises the efficiency of the network.
    
    b: float-type
    This constant controls the rate of Multiplicative Decrease. This optimises the fairness of the network.
    This value is between 0 (exclusive) and alpha (exclusive).
    
    With these two parameters, the network system converges to optimal network conditions where the fairness line intersects with the 
    efficiency line.
    
    cwnd: int-type
    This denotes the current window size.
    
    data_packet: tuple-type
    This represents the data packet to be transferred through the network.
    
    RTT_tracker: list-type
    This tracks the RTT to cwnd size.
    
    Returns
    -------
    cwnd load
    """
    _, status = data_packet
    
    if status == 'Transfer':
        cwnd += a
    else:
        cwnd = math.floor(cwnd * b)
        
    RTT_tracker.append(cwnd)
    
    return cwnd
        
if __name__ == "__main__":
    # Set Up for Data
    data_packets = [(x, "Transfer") if x % 5 != 0 else (x, "Dropped") for x in range(1, 51)]
    
    # Parameters
    cwnd = 10
    a = 1
    b = 0.3
    
    # Iterate
    RTT_tracker = []
    for data_packet in data_packets:
        cwnd = AIMD(a, b, cwnd, data_packet, RTT_tracker)
    
    # Visualise
    x, y = [], []
    for idx, cwnd in enumerate(RTT_tracker):
        print(f"RTT {idx + 1}:\t", cwnd)
        x.append(idx + 1)
        y.append(cwnd)
    
    plt.plot(x, y)
    plt.xlabel("RTT")
    plt.ylabel("CWND")
    plt.title(f"RTT vs CWND with a={a} and b={b}")
    plt.show()
# Out:
# RTT 1:	 11
# RTT 2:	 12
# RTT 3:	 13
# RTT 4:	 14
# RTT 5:	 4
# RTT 6:	 5
# RTT 7:	 6
# RTT 8:	 7
# RTT 9:	 8
# RTT 10:	 2
# RTT 11:	 3
# RTT 12:	 4
# RTT 13:	 5
# RTT 14:	 6
# RTT 15:	 1
# RTT 16:	 2
# RTT 17:	 3
# RTT 18:	 4
# RTT 19:	 5
# RTT 20:	 1
# RTT 21:	 2
# RTT 22:	 3
# RTT 23:	 4
# RTT 24:	 5
# RTT 25:	 1
# RTT 26:	 2
# RTT 27:	 3
# RTT 28:	 4
# RTT 29:	 5
# RTT 30:	 1
# RTT 31:	 2
# RTT 32:	 3
# RTT 33:	 4
# RTT 34:	 5
# RTT 35:	 1
# RTT 36:	 2
# RTT 37:	 3
# RTT 38:	 4
# RTT 39:	 5
# RTT 40:	 1
# RTT 41:	 2
# RTT 42:	 3
# RTT 43:	 4
# RTT 44:	 5
# RTT 45:	 1
# RTT 46:	 2
# RTT 47:	 3
# RTT 48:	 4
# RTT 49:	 5
# RTT 50:	 1

# %% [markdown]
# AIMD Tunning rough work

# %%
cwnd = [[4,3],[3,2],[10,3]]
num_users = 3

print(sum(cwnd[flow][-1] for flow in range(num_users)))

print(sum(cwnd[flow][-1] for flow in range(num_users)) <= 10)
# Out:
# 8
# True

# %%
print([flow[-1] for flow in cwnd])
# Out:
# [3, 2, 3]

# %%
alpha = 1
for flow in cwnd:
    new_flow_value = flow[-1] + alpha
    flow.append(new_flow_value)
print([flow[-1] for flow in cwnd])
# Out:
# [4, 3, 4]

# %%
print('==== Final Values ====')
i = 1
for flow in cwnd:

    print(f'User {i}: {flow[-1]}')
    i+= 1
# Out:
# ==== Final Values ====
# User 1: 4
# User 2: 3
# User 3: 4

# %%
print('==== Final Values ====')
for flow in range(len(cwnd)):
    print(f'User {flow+1}: {cwnd[flow][-1]}')
# Out:
# ==== Final Values ====
# User 1: 4
# User 2: 3
# User 3: 4

# %%
import matplotlib.pyplot as plt

capacity =10
cwnd = [[3.        , 4.        , 2.        , 3.        , 4.        ,
       5.        , 2.5       , 3.5       , 4.5       , 5.5       ,
       2.75      , 3.75      , 4.75      , 5.75      , 2.875     ,
       3.875     , 4.875     , 5.875     , 2.9375    , 3.9375    ,
       4.9375    , 5.9375    , 2.96875   , 3.96875   , 4.96875   ,
       5.96875   , 2.984375  , 3.984375  , 4.984375  , 5.984375  ,
       2.9921875 , 3.9921875 , 4.9921875 , 5.9921875 , 2.99609375,
       3.99609375, 4.99609375, 5.99609375, 2.99804688, 3.99804688,
       4.99804688, 5.99804688, 2.99902344, 3.99902344, 4.99902344,
       5.99902344, 2.99951172, 3.99951172, 4.99951172, 5.99951172,
       2.99975586, 3.99975586, 4.99975586, 5.99975586, 2.99987793,
       3.99987793, 4.99987793, 5.99987793, 2.99993896, 3.99993896,
       4.99993896, 5.99993896, 2.99996948, 3.99996948, 4.99996948,
       5.99996948, 2.99998474, 3.99998474, 4.99998474, 5.99998474,
       2.99999237, 3.99999237, 4.99999237, 5.99999237, 2.99999619,
       3.99999619, 4.99999619, 5.99999619, 2.99999809, 3.99999809,
       4.99999809, 5.99999809, 2.99999905, 3.99999905, 4.99999905,
       5.99999905, 2.99999952, 3.99999952, 4.99999952, 5.99999952,
       2.99999976, 3.99999976, 4.99999976, 5.99999976, 2.99999988,
       3.99999988, 4.99999988, 5.99999988, 2.99999994, 3.99999994], [6.        , 7.        , 3.5       , 4.5       , 5.5       ,
       6.5       , 3.25      , 4.25      , 5.25      , 6.25      ,
       3.125     , 4.125     , 5.125     , 6.125     , 3.0625    ,
       4.0625    , 5.0625    , 6.0625    , 3.03125   , 4.03125   ,
       5.03125   , 6.03125   , 3.015625  , 4.015625  , 5.015625  ,
       6.015625  , 3.0078125 , 4.0078125 , 5.0078125 , 6.0078125 ,
       3.00390625, 4.00390625, 5.00390625, 6.00390625, 3.00195312,
       4.00195312, 5.00195312, 6.00195312, 3.00097656, 4.00097656,
       5.00097656, 6.00097656, 3.00048828, 4.00048828, 5.00048828,
       6.00048828, 3.00024414, 4.00024414, 5.00024414, 6.00024414,
       3.00012207, 4.00012207, 5.00012207, 6.00012207, 3.00006104,
       4.00006104, 5.00006104, 6.00006104, 3.00003052, 4.00003052,
       5.00003052, 6.00003052, 3.00001526, 4.00001526, 5.00001526,
       6.00001526, 3.00000763, 4.00000763, 5.00000763, 6.00000763,
       3.00000381, 4.00000381, 5.00000381, 6.00000381, 3.00000191,
       4.00000191, 5.00000191, 6.00000191, 3.00000095, 4.00000095,
       5.00000095, 6.00000095, 3.00000048, 4.00000048, 5.00000048,
       6.00000048, 3.00000024, 4.00000024, 5.00000024, 6.00000024,
       3.00000012, 4.00000012, 5.00000012, 6.00000012, 3.00000006,
       4.00000006, 5.00000006, 6.00000006, 3.00000003, 4.00000003]]

plt.figure(figsize = (8, 8))        
for flow in range(2):
    print(flow)
    plt.plot(cwnd[flow], '-o', label=f'Flow {flow+1}')
plt.xlabel('RTT')
plt.ylabel('cwnd')

plt.grid()
plt.legend()
plt.show()
# Out:
# 0
# 1

# %%
initial = [2,3,3]
num_users = 3
if initial and len(initial)==num_users:
    cwnd = [[initial[i]] for i in range(num_users)]
    print(cwnd)
# Out:
# [[2], [3], [3]]

# %%
from random import seed, randint
seed(1)
cwnd = [[randint(1,10)] for i in range(num_users)]
print(cwnd)
# Out:
# [[3], [10], [2]]

# %%
cwnd = [[randint(1,10)] for i in range(num_users)]
cwnd
# Out:
# [[5], [2], [8]]

# %%
import math
math.floor(3 * 0.5)
# Out:
# 1

# %%
import numpy as np
import matplotlib.pyplot as plt

ITERATESMAX = 100
C = 10
alpha = 0.1
exponent1 = 2
exponent2 = 0.5
x1 = 1
x2 = 1
alpha1 = 0
alpha2 = 0
x1_values = np.zeros(ITERATESMAX)
x2_values = np.zeros(ITERATESMAX)

fairness_line = np.linspace(0, C, ITERATESMAX)  # Fairness line
capacity_line = np.full(ITERATESMAX, C)         # Capacity line

convergence_threshold = 0.1  # Adjust as needed

convergence_speed = np.zeros(ITERATESMAX)  # Store the convergence speed

for i in range(ITERATESMAX):
    if (x1 + x2 <= C):
        alpha1 = alpha * np.power(x1, exponent1)
        alpha2 = alpha * np.log(x2 + 1)
        x1 = x1 + alpha1
        x2 = x2 + alpha2
    else:
        beta1 = exponent1
        beta2 = exponent2
        x1 = x1 * beta1
        x2 = x2 * beta2
    
    x1_values[i] = x1
    x2_values[i] = x2

    # Compute convergence speed (difference between consecutive values)
    if i > 0:
        convergence_speed[i] = abs(x1_values[i] - x1_values[i-1]) + abs(x2_values[i] - x2_values[i-1])

# Plotting x1 vs x2
plt.plot(x1_values, x2_values, label='Flow Allocation')
plt.plot(fairness_line, fairness_line, '--', label='Fairness Line')
plt.plot(capacity_line, capacity_line, '--', label='Capacity Line')
plt.xlabel('x1 Values')
plt.ylabel('x2 Values')
plt.title('AIMD Algorithm Simulation')
plt.legend()
plt.show()

# Plotting convergence speed
plt.plot(convergence_speed, label='Convergence Speed')
plt.xlabel('Iterations')
plt.ylabel('Convergence Speed')
plt.title('Convergence Speed Analysis')
plt.legend()
plt.show()

# Check stability (convergence speed at the final iteration)
final_convergence_speed = convergence_speed[-1]

if final_convergence_speed < convergence_threshold:
    print("Stable: Convergence speed is low.")
else:
    print("Unstable: Convergence speed is high.")
# Out:
# Unstable: Convergence speed is high.
